# %%
import numpy as np
import pandas as pd
import datetime

file = 'center.csv'

raw_data = pd.read_csv(file,header=0, delimiter=',')
data = np.array(raw_data)

df = pd.DataFrame(data, columns = ['usage', 'supply','temp','date'])
df['supply'] = df['supply'].apply(pd.to_numeric)
df['usage'] = df['usage'].apply(pd.to_numeric)
df['temp'] = df['temp'].apply(pd.to_numeric)
df['date'] = df['date'].apply(pd.to_datetime)


print(df)
df.info()
# Out:
#      usage  supply  temp       date
# 0    763.5   869.9  31.1 2016-10-01
# 1    738.5   828.8  32.9 2016-10-02
# 2    820.0   950.2  31.3 2016-10-03
# 3    850.6   972.5  31.4 2016-10-04
# 4    835.6   966.0  31.7 2016-10-05
# 5    835.6   988.2  30.2 2016-10-06
# 6    859.0   960.3  28.2 2016-10-07
# 7    756.9   889.5  28.5 2016-10-08
# 8    684.7   856.8  27.5 2016-10-09
# 9    711.8   879.5  28.4 2016-10-10
# 10   827.2   966.8  30.0 2016-10-11
# 11   797.1   938.1  30.1 2016-10-12
# 12   795.6   931.1  30.8 2016-10-13
# 13   783.2   947.2  31.0 2016-10-14
# 14   734.3   892.5  32.1 2016-10-15
# 15   714.4   931.7  32.5 2016-10-16
# 16   848.3  1033.3  33.1 2016-10-17
# 17   842.1  1014.6  31.4 2016-10-18
# 18   843.4  1033.2  31.6 2016-10-19
# 19   855.9  1030.2  33.1 2016-10-20
# 20   854.4  1079.6  32.1 2016-10-21
# 21   765.6   894.2  32.5 2016-10-22
# 22   726.9   869.0  32.5 2016-10-23
# 23   834.8   999.3  32.2 2016-10-24
# 24   821.2   952.3  31.6 2016-10-25
# 25   854.7  1057.6  32.1 2016-10-26
# 26   854.4  1090.4  31.6 2016-10-27
# 27   837.4  1004.5  31.7 2016-10-28
# 28   721.5   854.9  30.6 2016-10-29
# 29   668.3   833.4  30.5 2016-10-30
# ..     ...     ...   ...        ...
# 243  835.5  1020.0  28.4 2017-06-01
# 244  841.8   971.6  28.8 2017-06-02
# 245  780.9   933.5  27.6 2017-06-03
# 246  702.9   985.4  29.0 2017-06-04
# 247  900.7   968.0  30.3 2017-06-05
# 248  925.0  1034.4  33.6 2017-06-06
# 249  947.0  1097.2  33.6 2017-06-07
# 250  891.2  1047.8  32.8 2017-06-08
# 251  904.2  1068.7  32.2 2017-06-09
# 252  846.9   938.6  33.5 2017-06-10
# 253  751.1   947.6  34.4 2017-06-11
# 254  916.9  1100.0  33.2 2017-06-12
# 255  910.1  1071.6  35.9 2017-06-13
# 256  841.4  1004.3  28.3 2017-06-14
# 257  814.9   928.1  25.1 2017-06-15
# 258  819.4   973.3  29.3 2017-06-16
# 259  739.2   864.4  26.5 2017-06-17
# 260  692.9   889.5  25.5 2017-06-18
# 261  813.5   969.4  29.4 2017-06-19
# 262  823.6   952.9  31.7 2017-06-20
# 263  863.7  1002.8  33.6 2017-06-21
# 264  872.1  1035.9  32.7 2017-06-22
# 265  924.2  1041.0  33.8 2017-06-23
# 266  827.5   962.6  33.7 2017-06-24
# 267  794.4  1038.0  33.0 2017-06-25
# 268  913.2  1007.4  33.8 2017-06-26
# 269  910.9  1024.9  32.8 2017-06-27
# 270  909.9  1037.8  33.7 2017-06-28
# 271  912.2  1020.2  33.2 2017-06-29
# 272  919.9  1011.1  34.0 2017-06-30
#
# [273 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 4 columns):
# usage     189 non-null float64
# supply    189 non-null float64
# temp      273 non-null float64
# date      273 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 8.6 KB

# %%
df['usage'].fillna(0, inplace=True)
df['supply'].fillna(0, inplace=True)

Q = np.array(df['supply'])
C = np.array(df['usage'])

# %%
import math

dist = math.sqrt(sum([(a-b)**2 for a,b in zip(Q,C)]))
print(dist)
# Out:
# 1767.0074844210476

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()

ax1.plot(df['date'], Q,label="Q",color='xkcd:sky blue')
ax1.plot(df['date'], C,label="C",color='xkcd:orange')
plt.title('original figure (Q:center supply, C:center usage)')
ax1.legend()
fig.autofmt_xdate()
plt.show()
fig.savefig('original.png', dpi=fig.dpi)

# %%
from scipy import signal

Q_de = scipy.signal.detrend(Q)
print(Q_de)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-87c2ced59d6f> in <module>()
# ----> 1 from scipy import signal
#       2
#       3 Q_de = scipy.signal.detrend(Q)
#       4 print(Q_de)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\scipy\signal\__init__.py in <module>()
#     302 from .spline import *
#     303
# --> 304 from .bsplines import *
#     305 from .filter_design import *
#     306 from .fir_filter_design import *
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\scipy\signal\bsplines.py in <module>()
#      10 from .spline import cspline2d, sepfir2d
#      11
# ---> 12 from scipy.special import comb, gamma
#      13
#      14 __all__ = ['spline_filter', 'bspline', 'gauss_spline', 'cubic', 'quadratic',
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\scipy\special\__init__.py in <module>()
#     638 from .sf_error import SpecialFunctionWarning, SpecialFunctionError
#     639
# --> 640 from ._ufuncs import *
#     641
#     642 from .basic import *
#
# ImportError: DLL load failed: 找不到指定的模組。

# %%
from scipy.spatial import distance
dst = distance.euclidean(Q,C)
print(dst)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-ccb31e8ff090> in <module>()
# ----> 1 from scipy.spatial import distance
#       2 dst = distance.euclidean(Q,C)
#       3 print(dst)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\scipy\spatial\__init__.py in <module>()
#      93 from .kdtree import *
#      94 from .ckdtree import *
# ---> 95 from .qhull import *
#      96 from ._spherical_voronoi import SphericalVoronoi
#      97 from ._plotutils import *
#
# ImportError: DLL load failed: 找不到指定的模組。
